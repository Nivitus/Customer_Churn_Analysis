# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
train_df = pd.read_csv('customer_churn.csv')
train_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
# Data Manipulation Methods
print(train_df.shape)
# Out:
# (7043, 21)

# %%
train_df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
print(train_df.columns)
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
train_df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# 5          False   False          False    False       False   False
# 6          False   False          False    False       False   False
# 7          False   False          False    False       False   False
# 8          False   False          False    False       False   False
# 9          False   False          False    False       False   False
# 10         False   False          False    False       False   False
# 11         False   False          False    False       False   False
# 12         False   False          False    False       False   False
# ...

# %%
train_df.head().isnull()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0       False   False          False    False       False   False
# 1       False   False          False    False       False   False
# 2       False   False          False    False       False   False
# 3       False   False          False    False       False   False
# 4       False   False          False    False       False   False
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0         False          False            False           False  ...
# 1         False          False            False           False  ...
# 2         False          False            False           False  ...
# 3         False          False            False           False  ...
# 4         False          False            False           False  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0             False        False        False            False     False
# ...

# %%
train_df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
train_df.head(7)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# ...

# %%
print(train_df['Dependents'].head(5))
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: Dependents, dtype: object

# %%
customer_5 = train_df['Dependents']
customer_5.head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: Dependents, dtype: object

# %%
c_5 = train_df.iloc[:,4]
c_5.head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: Dependents, dtype: object

# %%
c_random = train_df[(train_df['gender'] == "Male") & (train_df['SeniorCitizen'] == 1) & (train_df['PaymentMethod'] == "Electronic check")]
c_random
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 78    0191-ZHSKZ   Male              1      No         No      30
# 91    2424-WVHPL   Male              1      No         No       1
# 129   2639-UGMAZ   Male              1      No         No      71
# 168   3445-HXXGF   Male              1     Yes         No      58
# 214   2504-DSHIH   Male              1     Yes         No      23
# 245   0221-WMXNQ   Male              1      No         No       4
# 247   9947-OTFQU   Male              1      No         No      15
# 252   9514-JDSKI   Male              1     Yes         No       1
# 260   7273-TEFQD   Male              1      No         No       3
# 261   3606-TWKGI   Male              1      No         No      13
# ...

# %%
c_random.head(10)
# Out:
#      customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 20   8779-QRDMV   Male              1      No         No       1           No
# 55   1658-BYGOY   Male              1      No         No      18          Yes
# 57   5067-XJQFU   Male              1     Yes        Yes      66          Yes
# 78   0191-ZHSKZ   Male              1      No         No      30          Yes
# 91   2424-WVHPL   Male              1      No         No       1          Yes
# 129  2639-UGMAZ   Male              1      No         No      71           No
# 168  3445-HXXGF   Male              1     Yes         No      58           No
# 214  2504-DSHIH   Male              1     Yes         No      23          Yes
# 245  0221-WMXNQ   Male              1      No         No       4          Yes
# 247  9947-OTFQU   Male              1      No         No      15          Yes
#
#         MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
c_random2 = train_df[(train_df['tenure'] > 70) | (train_df['MonthlyCharges'] > 100)]
c_random2.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
# 14  5129-JLPIS    Male              0      No         No      25          Yes
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 8            Yes     Fiber optic             No  ...              Yes
# 12           Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
# 14            No     Fiber optic            Yes  ...              Yes
# 15           Yes     Fiber optic            Yes  ...              Yes
#
# ...

# %%
c_random3 = train_df[(train_df['Contract'] == "Two year") & (train_df['PaymentMethod'] == "Mailed check") & (train_df['Churn'] == "Yes")]
c_random3.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
# Every Time sampling results will be change
c_sample_333 = train_df.sample(n = 333)
c_sample_333.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2823  4884-LEVMQ    Male              0     Yes         No      39
# 4550  4625-XMOYM  Female              0     Yes        Yes      72
# 1549  4237-RLAQD    Male              0      No         No       1
# 5221  5336-UFNZP  Female              1     Yes        Yes      65
# 6307  3043-SUDUA  Female              0      No         No      32
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 2823          Yes            No              No  No internet service  ...
# 4550          Yes           Yes              No  No internet service  ...
# 1549          Yes            No             DSL                   No  ...
# 5221          Yes           Yes     Fiber optic                   No  ...
# 6307          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
train_df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
train_df['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
# Data Visualization

# %%
# Bar chart is always use to deal with the catogorical columns
plt.bar(train_df['InternetService'].value_counts().keys().tolist(), train_df['InternetService'].value_counts().tolist(),color = "Orange")
plt.xlabel("Catogories of Internet services")
plt.ylabel("Count")
plt.title("Distributions of Internet Services")
plt.show()

# %%
plt.hist(train_df['tenure'], bins = 30, color = 'Green')
plt.title("Distribution of tenure")
plt.show()

# %%
plt.scatter(x = train_df['tenure'], y = train_df['MonthlyCharges'])
plt.xlabel("tenure")
plt.ylabel("Monthly Charges")
plt.title("tenure vs Monthly Charges")
plt.show()

# %%
train_df.boxplot(column = ['tenure'],by = ['Contract'])

# %%
# Machine Learning Part:
# Linear Regression

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Y is an depented variable
# X is an in depented variable
y = train_df[['MonthlyCharges']]
x = train_df[['tenure']]

# %%
y.head(),x.head()
# Out:
# (   MonthlyCharges
#  0           29.85
#  1           56.95
#  2           53.85
#  3           42.30
#  4           70.70,    tenure
#  0       1
#  1      34
#  2       2
#  3      45
#  4       2)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = 0)
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((4930, 1), (4930, 1), (2113, 1), (2113, 1))

# %%
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([[60.95089608],
#        [72.98096699],
#        [59.1903979 ],
#        ...,
#        [75.62171426],
#        [70.63363608],
#        [65.6455579 ]])

# %%
y_pred = regressor.predict(x_test)
y_pred[:5],y_test[:5]
# Out:
# (array([[60.95089608],
#         [72.98096699],
#         [59.1903979 ],
#         [55.66940154],
#         [71.51388517]]),       MonthlyCharges
#  2200           58.20
#  4627          116.60
#  3225           71.95
#  2828           20.45
#  3768           77.75)

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 29.394584027273893

# %%
# Logistic Regression
# We got the Multiple Independent Variables such as MonthlyCharges and tenure

# %%
x = train_df[['MonthlyCharges','tenure']]
y = train_df[['Churn']]

# %%
# training set = 80% testing set = 20%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20,random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()
log_model.fit(x_train,y_train)
y_pred = log_model.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
confusion_matrix(y_test,y_pred),accuracy_score(y_test,y_pred)
# Out:
# (array([[935, 106],
#         [211, 157]], dtype=int64), 0.7750177430801988)

# %%
(935 + 157) / (935 + 157 + 211 + 106)
# Out:
# 0.7750177430801988

# %%
# Decision Tree

# %%
x = train_df[['tenure']]
y = train_df[['Churn']]

from sklearn.tree import DecisionTreeClassifier

# training set = 80% testing set = 20%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20,random_state = 0)

# %%
my_tree = DecisionTreeClassifier()
my_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
y_pred = my_tree.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[965,  76],
#        [281,  87]], dtype=int64)

# %%
(965 + 87) / (965 + 87 + 76 + 281)
# Out:
# 0.7466288147622427

# %%
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

Rf = RandomForestClassifier()
Rf.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
# ...

# %%
Rf.predict(x_test)
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'Yes'], dtype=object)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[965,  76],
#        [281,  87]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7466288147622427
